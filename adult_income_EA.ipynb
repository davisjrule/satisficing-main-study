# %%
# %pip install --upgrade fairlearn
# %pip install --upgrade interpret-community
# %pip install --upgrade raiwidgets
# Out:
# Requirement already satisfied: fairlearn in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (0.7.0)
# Requirement already satisfied: numpy>=1.17.2 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from fairlearn) (1.21.2)
# Requirement already satisfied: scikit-learn>=0.22.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from fairlearn) (0.24.2)
# Requirement already satisfied: scipy>=1.4.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from fairlearn) (1.7.1)
# Requirement already satisfied: pandas>=0.25.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from fairlearn) (1.3.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->fairlearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->fairlearn) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->fairlearn) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.1->fairlearn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.1->fairlearn) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: interpret-community in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (0.26.0)
# Requirement already satisfied: ml-wrappers==0.2.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community) (0.2.0)
# Requirement already satisfied: scikit-learn in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community) (0.24.2)
# Requirement already satisfied: packaging in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community) (21.0)
# Requirement already satisfied: numpy in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community) (1.21.2)
# Requirement already satisfied: pandas in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community) (1.3.3)
# Requirement already satisfied: scipy in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community) (1.7.1)
# Requirement already satisfied: shap<=0.40.0,>=0.20.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community) (0.39.0)
# Requirement already satisfied: interpret-core[required]<=0.2.7,>=0.1.20 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community) (0.2.7)
# Requirement already satisfied: joblib>=0.11 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-core[required]<=0.2.7,>=0.1.20->interpret-community) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from pandas->interpret-community) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from pandas->interpret-community) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->interpret-community) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->interpret-community) (2.2.0)
# Requirement already satisfied: numba in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from shap<=0.40.0,>=0.20.0->interpret-community) (0.53.1)
# Requirement already satisfied: slicer==0.0.7 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from shap<=0.40.0,>=0.20.0->interpret-community) (0.0.7)
# Requirement already satisfied: cloudpickle in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from shap<=0.40.0,>=0.20.0->interpret-community) (2.0.0)
# Requirement already satisfied: tqdm>4.25.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from shap<=0.40.0,>=0.20.0->interpret-community) (4.62.2)
# Requirement already satisfied: setuptools in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from numba->shap<=0.40.0,>=0.20.0->interpret-community) (58.0.4)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from numba->shap<=0.40.0,>=0.20.0->interpret-community) (0.36.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from packaging->interpret-community) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: raiwidgets in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (0.19.0)
# Requirement already satisfied: scikit-learn>=0.22.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (0.24.2)
# Requirement already satisfied: lightgbm>=2.0.11 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (3.2.1)
# Requirement already satisfied: responsibleai==0.19.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (0.19.0)
# Requirement already satisfied: fairlearn>=0.7.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (0.7.0)
# Requirement already satisfied: erroranalysis>=0.3.2 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (0.3.2)
# Requirement already satisfied: rai-core-flask==0.3.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (0.3.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (1.7.1)
# Requirement already satisfied: itsdangerous==2.0.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (2.0.1)
# Requirement already satisfied: jinja2==2.11.3 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (2.11.3)
# Requirement already satisfied: numpy>=1.17.2 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (1.21.2)
# Requirement already satisfied: pandas>=0.25.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiwidgets) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jinja2==2.11.3->raiwidgets) (2.0.1)
# Requirement already satisfied: Flask~=1.1.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from rai-core-flask==0.3.0->raiwidgets) (1.1.2)
# Requirement already satisfied: ipython==7.31.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from rai-core-flask==0.3.0->raiwidgets) (7.31.1)
# Requirement already satisfied: Flask-Cors==3.0.10 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from rai-core-flask==0.3.0->raiwidgets) (3.0.10)
# Requirement already satisfied: greenlet==1.1.2 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from rai-core-flask==0.3.0->raiwidgets) (1.1.2)
# Requirement already satisfied: gevent==21.12.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from rai-core-flask==0.3.0->raiwidgets) (21.12.0)
# Requirement already satisfied: Werkzeug<2.1.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from rai-core-flask==0.3.0->raiwidgets) (2.0.1)
# Requirement already satisfied: Six in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from Flask-Cors==3.0.10->rai-core-flask==0.3.0->raiwidgets) (1.16.0)
# Requirement already satisfied: setuptools in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from gevent==21.12.0->rai-core-flask==0.3.0->raiwidgets) (58.0.4)
# Requirement already satisfied: zope.event in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from gevent==21.12.0->rai-core-flask==0.3.0->raiwidgets) (4.5.0)
# Requirement already satisfied: zope.interface in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from gevent==21.12.0->rai-core-flask==0.3.0->raiwidgets) (5.4.0)
# Requirement already satisfied: pickleshare in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (0.7.5)
# Requirement already satisfied: backcall in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (0.2.0)
# Requirement already satisfied: pygments in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (2.10.0)
# Requirement already satisfied: matplotlib-inline in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (5.1.0)
# Requirement already satisfied: appnope in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (0.1.2)
# Requirement already satisfied: decorator in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (0.17.1)
# Requirement already satisfied: numba<0.54.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (0.53.1)
# Requirement already satisfied: econml~=0.12.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (0.12.0)
# Requirement already satisfied: dice-ml<0.9,>=0.8 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (0.8)
# Requirement already satisfied: semver~=2.13.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (2.13.0)
# Requirement already satisfied: ipykernel<=6.6.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (6.4.1)
# Requirement already satisfied: interpret-community>=0.25.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (0.26.0)
# Requirement already satisfied: raiutils>=0.1.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (0.1.0)
# Requirement already satisfied: networkx<=2.5 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (2.5)
# Requirement already satisfied: jsonschema in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from responsibleai==0.19.0->raiwidgets) (3.2.0)
# Requirement already satisfied: tqdm in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from dice-ml<0.9,>=0.8->responsibleai==0.19.0->raiwidgets) (4.62.2)
# Requirement already satisfied: h5py in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from dice-ml<0.9,>=0.8->responsibleai==0.19.0->raiwidgets) (2.10.0)
# Requirement already satisfied: statsmodels>=0.10 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (0.12.2)
# Requirement already satisfied: joblib>=0.13.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (1.0.1)
# Requirement already satisfied: dowhy in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (0.7.1)
# Requirement already satisfied: sparse in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (0.13.0)
# Requirement already satisfied: shap<0.40.0,>=0.38.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (0.39.0)
# Requirement already satisfied: click>=5.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from Flask~=1.1.0->rai-core-flask==0.3.0->raiwidgets) (8.0.1)
# Requirement already satisfied: ml-wrappers==0.2.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community>=0.25.0->responsibleai==0.19.0->raiwidgets) (0.2.0)
# Requirement already satisfied: packaging in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community>=0.25.0->responsibleai==0.19.0->raiwidgets) (21.0)
# Requirement already satisfied: interpret-core[required]<=0.2.7,>=0.1.20 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from interpret-community>=0.25.0->responsibleai==0.19.0->raiwidgets) (0.2.7)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (7.0.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (6.1)
# Requirement already satisfied: ipython-genutils in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (0.7.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (22.2.1)
# Requirement already satisfied: entrypoints in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel<=6.6.0->responsibleai==0.19.0->raiwidgets) (4.8.1)
# Requirement already satisfied: wheel in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from lightgbm>=2.0.11->raiwidgets) (0.37.0)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from numba<0.54.0->responsibleai==0.19.0->raiwidgets) (0.36.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->raiwidgets) (2021.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.31.1->rai-core-flask==0.3.0->raiwidgets) (0.2.5)
# Requirement already satisfied: requests in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from raiutils>=0.1.0->responsibleai==0.19.0->raiwidgets) (2.26.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.1->raiwidgets) (2.2.0)
# Requirement already satisfied: slicer==0.0.7 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from shap<0.40.0,>=0.38.1->econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (0.0.7)
# Requirement already satisfied: cloudpickle in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from shap<0.40.0,>=0.38.1->econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (2.0.0)
# Requirement already satisfied: patsy>=0.5 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from statsmodels>=0.10->econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (0.5.2)
# Requirement already satisfied: sympy>=1.4 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from dowhy->econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (1.8)
# Requirement already satisfied: pydot>=1.4 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from dowhy->econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from pydot>=1.4->dowhy->econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (2.4.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from sympy>=1.4->dowhy->econml~=0.12.0->responsibleai==0.19.0->raiwidgets) (1.2.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->responsibleai==0.19.0->raiwidgets) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->responsibleai==0.19.0->raiwidgets) (0.17.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from requests->raiutils>=0.1.0->responsibleai==0.19.0->raiwidgets) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from requests->raiutils>=0.1.0->responsibleai==0.19.0->raiwidgets) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from requests->raiutils>=0.1.0->responsibleai==0.19.0->raiwidgets) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/davisrule/opt/anaconda3/lib/python3.8/site-packages (from requests->raiutils>=0.1.0->responsibleai==0.19.0->raiwidgets) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# libraries
from fairlearn.reductions import GridSearch
from fairlearn.reductions import DemographicParity
from fairlearn.datasets import fetch_adult
from fairlearn.metrics import MetricFrame, selection_rate

from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score

import pandas as pd

# SHAP Tabular Explainer
from interpret.ext.blackbox import MimicExplainer
from interpret.ext.glassbox import LGBMExplainableModel

# %%
import numpy as np
from random import shuffle
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("adult_income_orig.csv")

df.columns = [
        "Age", "WorkClass", "fnlwgt", "Education", "EducationNum",
        "MaritalStatus", "Occupation", "Relationship", "Race", "Gender",
        "CapitalGain", "CapitalLoss", "HoursPerWeek", "NativeCountry", "Income"]

def convert_hours(x):
    if x < 30:
        return "0-30"
    elif x < 60:
        return "30-60"
    elif x < 90:
        return "60-90"
    else:
        return "90+"

df['HoursPerWeek'] = df['HoursPerWeek'].apply(lambda x: convert_hours(x))

cols = [
        "Age", "WorkClass", "Education","EducationNum", "MaritalStatus", "Occupation", "Race", "Gender",
        "CapitalGain", "CapitalLoss", "HoursPerWeek", "NativeCountry", "Income"]
df = df[cols]


train_cols = df.columns[0:-1]
label = df.columns[-1]
X_df = df[train_cols]
y_df = df[label]

X_display = X_df.copy()

#Converting strings to integers and floats for categorical data
categorical_cols = ["WorkClass", "Education", "MaritalStatus", "Occupation", "Race", "Gender", "NativeCountry", "HoursPerWeek"]

for col in categorical_cols:
    X_df[col] = pd.Categorical(X_df[col])
    X_df[col] = X_df[col].cat.codes


#Converting the response / output variable to a binary class
y_df = y_df.apply(lambda x: 0 if x == " <=50K" else 1)

dataset = {
        'X': X_df,
        'y': y_df,
}

le = LabelEncoder()
y = le.fit_transform(y_df)

#Top 5 rows of the original dataset:
df.head()
# Out:
#    Age          WorkClass   Education  EducationNum        MaritalStatus  \
# 0   39          State-gov   Bachelors            13        Never-married
# 1   50   Self-emp-not-inc   Bachelors            13   Married-civ-spouse
# 2   38            Private     HS-grad             9             Divorced
# 3   53            Private        11th             7   Married-civ-spouse
# 4   28            Private   Bachelors            13   Married-civ-spouse
#
#            Occupation    Race   Gender  CapitalGain  CapitalLoss HoursPerWeek  \
# 0        Adm-clerical   White     Male         2174            0        30-60
# 1     Exec-managerial   White     Male            0            0         0-30
# 2   Handlers-cleaners   White     Male            0            0        30-60
# 3   Handlers-cleaners   Black     Male            0            0        30-60
# 4      Prof-specialty   Black   Female            0            0        30-60
#
#     NativeCountry  Income
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
from sklearn.model_selection import train_test_split

# create a train/test split
seed = 1
X_train, X_test, y_train, y_test = train_test_split(dataset['X'],dataset['y'], test_size=0.25, random_state=seed)

# %%
numeric_transformer = Pipeline(
    steps=[
        ("impute", SimpleImputer()),
        ("scaler", StandardScaler()),
    ]
)
categorical_transformer = Pipeline(
    [
        ("impute", SimpleImputer(strategy="most_frequent")),
        ("ohe", OneHotEncoder(handle_unknown="ignore")),
    ]
)
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, make_column_selector(dtype_exclude="category")),
        ("cat", categorical_transformer, make_column_selector(dtype_include="category")),
    ]
)

model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "classifier",
            LogisticRegression(solver="liblinear", fit_intercept=True),
        ),
    ]
)

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fad24014ca0>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fad240147f0>)])),
#                 ('classifier', LogisticRegression(solver='liblinear'))])

# %%
# Using SHAP MimicExplainer
# clf.steps[-1][1] returns the trained classification model
explainer = MimicExplainer(model.steps[-1][1], 
                           X_train,
                           LGBMExplainableModel,
                           features=X_df.columns, 
                           classes=['Rejected', 'Approved'],
                           transformations=preprocessor)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /var/folders/zk/gq_1njv54tn9pvbmfr94gx5m0000gn/T/ipykernel_87515/3136721966.py in <module>
#       1 # Using SHAP MimicExplainer
#       2 # clf.steps[-1][1] returns the trained classification model
# ----> 3 explainer = MimicExplainer(model.steps[-1][1],
#       4                            X_train,
#       5                            LGBMExplainableModel,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/dataset/decorator.py in init_wrapper(self, model, initialization_examples, *args, **kwargs)
#      41     @wraps(init_func)
#      42     def init_wrapper(self, model, initialization_examples, *args, **kwargs):
# ---> 43         return init_func(self, model, wrap_dataset(initialization_examples), *args, **kwargs)
#      44     return init_wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/mimic/mimic_explainer.py in __init__(self, model, initialization_examples, explainable_model, explainable_model_args, is_function, augment_data, max_num_of_augmentations, explain_subset, features, classes, transformations, allow_all_transformations, shap_values_output, categorical_features, model_task, reset_index, **kwargs)
#     244         self._datamapper = None
#     245         if transformations is not None:
# --> 246             self._datamapper, new_initialization_examples = get_datamapper_and_transformed_data(
#     247                 examples=initialization_examples, transformations=transformations,
#     248                 allow_all_transformations=allow_all_transformations)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/_internal/raw_explain/raw_explain_utils.py in get_datamapper_and_transformed_data(examples, transformations, allow_all_transformations)
#      49     data_mapper = DataMapper(transformations, allow_all_transformations=allow_all_transformations)
#      50     if examples is not None:
# ---> 51         examples = transform_with_datamapper(examples, data_mapper)
#      52
#      53     return data_mapper, examples
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/_internal/raw_explain/raw_explain_utils.py in transform_with_datamapper(x, datamapper)
#      24     if x_is_dataset_wrapper:
#      25         input_data = x.original_dataset_with_type
# ---> 26     transformed_x = datamapper.transform(input_data)
#      27
#      28     if x_is_dataset_wrapper:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/_internal/raw_explain/data_mapper.py in transform(self, x)
#     220             # pass a single example through the transformations list to build feature map
#     221             columns = x.columns if isinstance(x, pandas.DataFrame) else list(range(x.shape[1]))
# --> 222             self._build_feature_map(x[:1], columns)
#     223
#     224         return self._transform(x)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/_internal/raw_explain/data_mapper.py in _build_feature_map(self, x, columns)
#     177         """
#     178         # run all transform methods in feature mappers so that we have column counts filled in
# --> 179         self._run_feature_mappers_transform(x)
#     180
#     181         num_output_columns = int(sum([x[1].feature_map.shape[1] for x in self._feature_mappers_pipeline]))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/_internal/raw_explain/data_mapper.py in _run_feature_mappers_transform(self, x)
#     207         """
#     208         for transformer_config, feature_mapper in self._feature_mappers_pipeline:
# --> 209             feature_mapper.transform(extract_column(x, transformer_config))
#     210
#     211     def transform(self, x):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/_internal/raw_explain/feature_mappers.py in transform(self, x)
#     199         :rtype: numpy.ndarray or scipy.sparse matrix
#     200         """
# --> 201         ret = self.transformer.transform(x)
#     202         if self._feature_map is None:
#     203             self._build_feature_map([s[1] for s in self._transformer.steps])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in _transform(self, X)
#     558         Xt = X
#     559         for _, _, transform in self._iter():
# --> 560             Xt = transform.transform(Xt)
#     561         return Xt
#     562
#
# ~/opt/anaconda3/lib/python3.8/site-packages/interpret_community/_internal/raw_explain/feature_mappers.py in transform(self, x)
#     126         :rtype: numpy.ndarray
#     127         """
# --> 128         result = self.transformer.transform(x)
#     129         if self._feature_map is None:
#     130             self._build_feature_map(result.shape[1])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/impute/_base.py in transform(self, X)
#     428             The input data to complete.
#     429         """
# --> 430         check_is_fitted(self)
#     431
#     432         X = self._validate_input(X, in_fit=False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This SimpleImputer instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
